# %%
# importing necessary libraries and packages
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn as sk
import matplotlib.pyplot as plt

# %%
# loading dataset 
df = pd.read_csv("Churn_Modelling.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# **Visualizations**

# %% [markdown]
# ***`1.Univariate Analysis`***

# %%
sns.displot(df['Age'], kde=True, bins=10)

# %% [markdown]
# **`2.Bi-Variate Analysis`**

# %%
sns.jointplot(x='Age', y='Tenure', data=df, kind="kde")

# %% [markdown]
# **`3.Multi-Variate Analysis`**

# %%
sns.lineplot(df['Age'], df['EstimatedSalary'], df['Balance'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **`Descriptive Statistics`**

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df['NumOfProducts'].sum()
# Out:
# 15302

# %%
df['Balance'].mean()
# Out:
# 100090.239881

# %%
df['Age'].mode()
# Out:
# 0    37
# dtype: int64

# %%
df['EstimatedSalary'].median()
# Out:
# 100193.915

# %% [markdown]
# **`Handling the Missing values`**

# %%
# isnull() returns boolean value which shows us the whether a data is null or not
df.isnull()
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender    Age  \
# 0         False       False    False        False      False   False  False
# 1         False       False    False        False      False   False  False
# 2         False       False    False        False      False   False  False
# 3         False       False    False        False      False   False  False
# 4         False       False    False        False      False   False  False
# ...         ...         ...      ...          ...        ...     ...    ...
# 9995      False       False    False        False      False   False  False
# 9996      False       False    False        False      False   False  False
# 9997      False       False    False        False      False   False  False
# 9998      False       False    False        False      False   False  False
# 9999      False       False    False        False      False   False  False
#
# ...

# %%
# to get the total null values column wise we use sum()
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# to get the total number null values present in the dataset we can use sum() again
df.isnull().sum().sum()
# Out:
# 0

# %%
# since the dataset does'nt have any null values we can't perform any operation on it.

# %% [markdown]
# **`Find the outliers and replace the outliers`**

# %%
qnt = df.quantile(q=(0.25, 0.75))
qnt
# Out:
#       RowNumber   CustomerId  CreditScore   Age  Tenure    Balance  \
# 0.25    2500.75  15628528.25        584.0  32.0     3.0       0.00
# 0.75    7500.25  15753233.75        718.0  44.0     7.0  127644.24
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0.25            1.0        0.0             0.0       51002.1100     0.0
# 0.75            2.0        1.0             1.0      149388.2475     0.0

# %%
iqr = qnt.loc[0.75] = qnt.loc[0.25]
iqr
# Out:
# RowNumber              2500.75
# CustomerId         15628528.25
# CreditScore             584.00
# Age                      32.00
# Tenure                    3.00
# Balance                   0.00
# NumOfProducts             1.00
# HasCrCard                 0.00
# IsActiveMember            0.00
# EstimatedSalary       51002.11
# Exited                    0.00
# Name: 0.25, dtype: float64

# %%
lower = qnt.loc[0.25] - 1.5 * iqr
lower
# Out:
# RowNumber            -1250.375
# CustomerId        -7814264.125
# CreditScore           -292.000
# Age                    -16.000
# Tenure                  -1.500
# Balance                  0.000
# NumOfProducts           -0.500
# HasCrCard                0.000
# IsActiveMember           0.000
# EstimatedSalary     -25501.055
# Exited                   0.000
# Name: 0.25, dtype: float64

# %%
upper = qnt.loc[0.75] + 1.5 * iqr
upper
# Out:
# RowNumber          6.251875e+03
# CustomerId         3.907132e+07
# CreditScore        1.460000e+03
# Age                8.000000e+01
# Tenure             7.500000e+00
# Balance            0.000000e+00
# NumOfProducts      2.500000e+00
# HasCrCard          0.000000e+00
# IsActiveMember     0.000000e+00
# EstimatedSalary    1.275053e+05
# Exited             0.000000e+00
# dtype: float64

# %%
print((df.head(10) < lower) | (df.head(10) > upper))
# Out:
#      Age  Balance  CreditScore  CustomerId  EstimatedSalary  Exited  Gender  \
# 0  False    False        False       False            False    True   False
# 1  False     True        False       False            False   False   False
# 2  False     True        False       False            False    True   False
# 3  False    False        False       False            False   False   False
# 4  False     True        False       False            False   False   False
# 5  False     True        False       False             True    True   False
# 6  False    False        False       False            False   False   False
# 7  False     True        False       False            False    True   False
# 8  False     True        False       False            False   False   False
# 9  False     True        False       False            False   False   False
#
#    Geography  HasCrCard  IsActiveMember  NumOfProducts  RowNumber  Surname  \
# ...

# %%
# identifying outliers with visualizations
sns.scatterplot(x='Age', y='Tenure', data=df)

# %%
# replacing outlier using median values

# %%
print(df['Age'].median())
print(df['Tenure'].median())
# Out:
# 37.0
# 10.0

# %%
df['Age'] = np.where(df['Age']>87, 40, df['Age'])
df['Tenure'] = np.where(df['Tenure'] > 85, 31, df['Tenure'])
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.906600      7.110800
# std     2886.89568  7.193619e+04     96.653299     10.449392      3.977299
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000     10.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000     10.000000
# max    10000.00000  1.581569e+07    850.000000     85.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
sns.boxplot(x=df['Tenure'])

# %% [markdown]
# **`Check for Categorical columns and perform encoding`**

# %%
df.head(2)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.00              1          1               1
# 1       1  83807.86              1          0               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0

# %%
df['Gender'].replace({"Female":0, "Male":1},inplace=True)
df['Exited'].replace({"yes":0, "No":1},inplace=True)

# %%
df_main = pd.get_dummies(df, columns=['Geography'])

# %%
df_main.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Gender  Age  Tenure  \
# 0          1    15634602  Hargrave          619       0   42       2
# 1          2    15647311      Hill          608       0   41       1
# 2          3    15619304      Onio          502       0   42      10
# 3          4    15701354      Boni          699       0   39       1
# 4          5    15737888  Mitchell          850       0   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited  Geography_France  Geography_Germany  Geography_Spain
# ...

# %%
y = df_main['Balance']

# %%
x = df_main.drop(columns=['Balance'],axis=1)

# %%
x.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Gender  Age  Tenure  \
# 0          1    15634602  Hargrave          619       0   42       2
# 1          2    15647311      Hill          608       0   41       1
# 2          3    15619304      Onio          502       0   42      10
# 3          4    15701354      Boni          699       0   39       1
# 4          5    15737888  Mitchell          850       0   43       2
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#    Geography_France  Geography_Germany  Geography_Spain
# 0                 1                  0                0
# ...

# %% [markdown]
# **`Split the data into dependent and independent variables`**

# %%
# Independent
x = df.iloc[:,0:3]
x
# Out:
#       RowNumber  CustomerId    Surname
# 0             1    15634602   Hargrave
# 1             2    15647311       Hill
# 2             3    15619304       Onio
# 3             4    15701354       Boni
# 4             5    15737888   Mitchell
# ...         ...         ...        ...
# 9995       9996    15606229   Obijiaku
# 9996       9997    15569892  Johnstone
# 9997       9998    15584532        Liu
# 9998       9999    15682355  Sabbatini
# 9999      10000    15628319     Walker
#
# [10000 rows x 3 columns]

# %%
# Dependent

y = df['Exited']
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
x = df_main.drop(columns=['Surname'],axis=1)

# %%
names = x.columns

# %%
names
# Out:
# Index(['RowNumber', 'CustomerId', 'CreditScore', 'Gender', 'Age', 'Tenure',
#        'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited', 'Geography_France', 'Geography_Germany',
#        'Geography_Spain'],
#       dtype='object')

# %% [markdown]
# **`Scale the independent variables`**

# %%
from sklearn.preprocessing import scale

# %%
x = scale(x)

# %%
x
# Out:
# array([[-1.73187761, -0.78321342, -0.32622142, ...,  0.99720391,
#         -0.57873591, -0.57380915],
#        [-1.7315312 , -0.60653412, -0.44003595, ..., -1.00280393,
#         -0.57873591,  1.74273971],
#        [-1.73118479, -0.99588476, -1.53679418, ...,  0.99720391,
#         -0.57873591, -0.57380915],
#        ...,
#        [ 1.73118479, -1.47928179,  0.60498839, ...,  0.99720391,
#         -0.57873591, -0.57380915],
#        [ 1.7315312 , -0.11935577,  1.25683526, ..., -1.00280393,
#          1.72790383, -0.57380915],
#        [ 1.73187761, -0.87055909,  1.46377078, ...,  0.99720391,
#         -0.57873591, -0.57380915]])

# %%
x = pd.DataFrame(x, columns=names)

# %%
x.head()
# Out:
#    RowNumber  CustomerId  CreditScore    Gender       Age    Tenure   Balance  \
# 0  -1.731878   -0.783213    -0.326221 -1.095988  0.296051 -1.285057 -1.225848
# 1  -1.731531   -0.606534    -0.440036 -1.095988  0.200347 -1.536496  0.117350
# 2  -1.731185   -0.995885    -1.536794 -1.095988  0.296051  0.726459  1.333053
# 3  -1.730838    0.144767     0.501521 -1.095988  0.008939 -1.536496 -1.225848
# 4  -1.730492    0.652659     2.063884 -1.095988  0.391755 -1.285057  0.785728
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary    Exited  \
# 0      -0.911583   0.646092        0.970243         0.021886  1.977165
# 1      -0.911583  -1.547768        0.970243         0.216534 -0.505775
# 2       2.527057   0.646092       -1.030670         0.240687  1.977165
# 3       0.807737  -1.547768       -1.030670        -0.108918 -0.505775
# 4      -0.911583   0.646092        0.970243        -0.365276 -0.505775
#
#    Geography_France  Geography_Germany  Geography_Spain
# ...

# %% [markdown]
# **`Split the data into training and testing`**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
x_train.head()
# Out:
#       RowNumber  CustomerId  CreditScore    Gender       Age    Tenure  \
# 7389   0.827747   -0.195066     0.170424 -1.095988 -0.469582  0.726459
# 9275   1.481077    0.810821    -2.312802  0.912419  0.296051 -1.536496
# 2995  -0.694379   -1.507642    -1.195351 -1.095988 -0.948103 -1.285057
# 5316   0.109639    1.243462     0.035916  0.912419  0.104643  0.726459
# 356   -1.608556   -1.100775     2.063884 -1.095988  1.731613  0.726459
#
#        Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 7389 -1.225848       0.807737   0.646092       -1.030670         1.108382
# 9275 -0.012892      -0.911583   0.646092        0.970243        -0.747592
# 2995  0.575076      -0.911583   0.646092       -1.030670         1.487464
# 5316  0.467955      -0.911583   0.646092       -1.030670         1.278558
# 356   0.806010       0.807737   0.646092        0.970243         0.560069
#
#         Exited  Geography_France  Geography_Germany  Geography_Spain
# ...

# %%
x_test.head()
# Out:
#       RowNumber  CustomerId  CreditScore    Gender       Age    Tenure  \
# 9394   1.522299   -1.045250    -0.553850 -1.095988 -0.373878  0.726459
# 898   -1.420801   -0.503813    -1.319512 -1.095988  0.104643 -1.285057
# 2398  -0.901186   -0.793292     0.573948 -1.095988  0.296051  0.726459
# 5906   0.314021    0.760190     1.422384  0.912419 -0.660990  0.726459
# 2343  -0.920239    1.042107     0.573948  0.912419 -0.086765  0.726459
#
#        Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 9394  0.875323      -0.911583   0.646092        0.970243         1.613046
# 898   0.424422      -0.911583   0.646092       -1.030670         0.497532
# 2398  0.302927      -0.911583   0.646092        0.970243        -0.423561
# 5906  0.570464      -0.911583  -1.547768       -1.030670        -0.186439
# 2343  1.387129       0.807737   0.646092        0.970243         0.618560
#
#         Exited  Geography_France  Geography_Germany  Geography_Spain
# ...

# %%
y_train, y_test
# Out:
# (7389    0
#  9275    0
#  2995    0
#  5316    0
#  356     0
#         ..
#  9225    0
#  4859    0
#  3264    0
#  9845    0
#  2732    1
#  Name: Exited, Length: 8000, dtype: int64, 9394    0
#  898     1
#  2398    0
#  5906    0
#  2343    0
#         ..
#  1037    0
#  2899    0
#  9549    0
#  2740    0
#  6690    0
#  Name: Exited, Length: 2000, dtype: int64)
